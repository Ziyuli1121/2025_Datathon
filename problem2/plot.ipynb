# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the feature importance data
data = {
    "feature": [
        "prev_balance_mean", "cu_cur_balance", "cu_crd_line", "delinquency_risk",
        "ca_max_dlq_lst_6_mnths", "credit_utilization", "ca_avg_utilz_lst_6_mnths",
        "cu_cur_nbr_due", "behavior_score_combined", "cu_nbr_days_dlq",
        "balance_ratio", "external_credit_score", "sales_growth_rate", "has_fraud"
    ],
    "importance": [
        0.23898102285693978, 0.15940955592347672, 0.15556265892131915, 0.11269288521187057,
        0.08934204920673916, 0.06085146739889722, 0.03870160834486017, 0.035477239456906694,
        0.03390610438010924, 0.03301363382541119, 0.027125517629891564, 0.011059014317587839,
        0.003620568469380767, 0.0002566740566099789
    ]
}

df = pd.DataFrame(data)

# Sort by importance
df_sorted = df.sort_values(by="importance", ascending=True)

# Plot
plt.figure(figsize=(10, 6))
plt.barh(df_sorted["feature"], df_sorted["importance"])
plt.xlabel("Importance")
plt.title("Feature Importance")
plt.tight_layout()
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
